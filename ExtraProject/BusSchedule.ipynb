# %%
#This is my first own project (early 2020). The goal is to learn Python loops, time data and variable types.
#The idea is, having a set of made-up buses or trains through a number of Spanish cities, with schedules of
#each of the stops, find the possible connections within 2 cities, even when they are not directly connected.

# %%
from collections import OrderedDict
from datetime import time

# %%
def Sch(line):
    for k,v in line.items():
        print ('\t'+k, v)

# %%
#This is the amount of buses I create. Each variable has the information for one bus service, its ID, 
#and the time where it stops at each of the cities.

EU1201 = OrderedDict()
EU1201[' ']  = 'EU1201'
EU1201['BCN'] = time( 6,  0).isoformat(timespec='minutes')
EU1201['TRG'] = time( 7, 15).isoformat(timespec='minutes')
EU1201['VLC'] = time( 9, 45).isoformat(timespec='minutes')
EU1201['ALC'] = time(11, 20).isoformat(timespec='minutes')
EU1201['MLG'] = time(14,  0).isoformat(timespec='minutes')
EU1201['SEV'] = time(16, 30).isoformat(timespec='minutes')

EU1202 = OrderedDict()
EU1202[' ']  = 'EU1202'
EU1202['BCN'] = time( 8,  0).isoformat(timespec='minutes')
EU1202['TRG'] = time( 9, 15).isoformat(timespec='minutes')
EU1202['VLC'] = time(11, 45).isoformat(timespec='minutes')
EU1202['ALC'] = time(13, 20).isoformat(timespec='minutes')
EU1202['MLG'] = time(16,  0).isoformat(timespec='minutes')
EU1202['SEV'] = time(18, 30).isoformat(timespec='minutes')

EU1203 = OrderedDict()
EU1203[' ']  = 'EU1203'
EU1203['BCN'] = time(10,  0).isoformat(timespec='minutes')
EU1203['TRG'] = time(11,  5).isoformat(timespec='minutes')
EU1203['VLC'] = time(13, 25).isoformat(timespec='minutes')
EU1203['ALC'] = time(14, 50).isoformat(timespec='minutes')
EU1203['MLG'] = time(17, 10).isoformat(timespec='minutes')
EU1203['SEV'] = time(19, 25).isoformat(timespec='minutes')

EU1204 = OrderedDict()
EU1204[' ']  = 'EU1204'
EU1204['BCN'] = time(12,  0).isoformat(timespec='minutes')
EU1204['TRG'] = time(13, 15).isoformat(timespec='minutes')
EU1204['VLC'] = time(15, 45).isoformat(timespec='minutes')
EU1204['ALC'] = time(17, 10).isoformat(timespec='minutes')
EU1204['MLG'] = time(19, 45).isoformat(timespec='minutes')
EU1204['SEV'] = time(22, 20).isoformat(timespec='minutes')

EU1205 = OrderedDict()
EU1205[' ']  = 'EU1205'
EU1205['BCN'] = time(14,  0).isoformat(timespec='minutes')
EU1205['TRG'] = time(15, 15).isoformat(timespec='minutes')
EU1205['VLC'] = time(17, 35).isoformat(timespec='minutes')
EU1205['ALC'] = time(19,  0).isoformat(timespec='minutes')
EU1205['MLG'] = time(21, 35).isoformat(timespec='minutes')
EU1205['SEV'] = time(23, 55).isoformat(timespec='minutes')

EU1301 = OrderedDict()
EU1301[' ']  = 'EU1301'
EU1301['SEV'] = time( 6, 15).isoformat(timespec='minutes')
EU1301['MLG'] = time( 8, 45).isoformat(timespec='minutes')
EU1301['ALC'] = time(11, 25).isoformat(timespec='minutes')
EU1301['VLC'] = time(13,  0).isoformat(timespec='minutes')
EU1301['TRG'] = time(15, 30).isoformat(timespec='minutes')
EU1301['BCN'] = time(16, 45).isoformat(timespec='minutes')

EU1302 = OrderedDict()
EU1302[' ']  = 'EU1302'
EU1302['SEV'] = time( 8,  0).isoformat(timespec='minutes')
EU1302['MLG'] = time(10, 30).isoformat(timespec='minutes')
EU1302['ALC'] = time(13, 10).isoformat(timespec='minutes')
EU1302['VLC'] = time(14, 55).isoformat(timespec='minutes')
EU1302['TRG'] = time(17, 25).isoformat(timespec='minutes')
EU1302['BCN'] = time(18, 40).isoformat(timespec='minutes')

EU1303 = OrderedDict()
EU1303[' ']  = 'EU1303'
EU1303['SEV'] = time(10,  0).isoformat(timespec='minutes')
EU1303['MLG'] = time(12, 30).isoformat(timespec='minutes')
EU1303['ALC'] = time(15, 10).isoformat(timespec='minutes')
EU1303['VLC'] = time(16, 55).isoformat(timespec='minutes')
EU1303['TRG'] = time(19, 25).isoformat(timespec='minutes')
EU1303['BCN'] = time(20, 40).isoformat(timespec='minutes')

EU1304 = OrderedDict()
EU1304[' ']  = 'EU1304'
EU1304['SEV'] = time(12,  0).isoformat(timespec='minutes')
EU1304['MLG'] = time(14, 30).isoformat(timespec='minutes')
EU1304['ALC'] = time(17, 10).isoformat(timespec='minutes')
EU1304['VLC'] = time(18, 50).isoformat(timespec='minutes')
EU1304['TRG'] = time(21, 15).isoformat(timespec='minutes')
EU1304['BCN'] = time(22, 25).isoformat(timespec='minutes')

EU1305 = OrderedDict()
EU1305[' ']  = 'EU1305'
EU1305['SEV'] = time(13, 45).isoformat(timespec='minutes')
EU1305['MLG'] = time(16, 15).isoformat(timespec='minutes')
EU1305['ALC'] = time(19,  0).isoformat(timespec='minutes')
EU1305['VLC'] = time(20, 30).isoformat(timespec='minutes')
EU1305['TRG'] = time(22, 45).isoformat(timespec='minutes')
EU1305['BCN'] = time(23, 50).isoformat(timespec='minutes')

EU2101 = OrderedDict()
EU2101[' ']  = 'EU2101'
EU2101['SEV'] = time( 6, 30).isoformat(timespec='minutes')
EU2101['TOL'] = time( 9, 15).isoformat(timespec='minutes')
EU2101['MAD'] = time(10,  0).isoformat(timespec='minutes')
EU2101['ZGZ'] = time(13,  0).isoformat(timespec='minutes')

EU2102 = OrderedDict()
EU2102[' ']  = 'EU2102'
EU2102['SEV'] = time( 9,  0).isoformat(timespec='minutes')
EU2102['TOL'] = time(11, 45).isoformat(timespec='minutes')
EU2102['MAD'] = time(12, 30).isoformat(timespec='minutes')
EU2102['ZGZ'] = time(15, 30).isoformat(timespec='minutes')

EU2103 = OrderedDict()
EU2103[' ']  = 'EU2103'
EU2103['SEV'] = time(11, 15).isoformat(timespec='minutes')
EU2103['TOL'] = time(14,  0).isoformat(timespec='minutes')
EU2103['MAD'] = time(14, 45).isoformat(timespec='minutes')
EU2103['ZGZ'] = time(17, 45).isoformat(timespec='minutes')

EU2104 = OrderedDict()
EU2104[' ']  = 'EU2104'
EU2104['SEV'] = time(13, 30).isoformat(timespec='minutes')
EU2104['TOL'] = time(16, 15).isoformat(timespec='minutes')
EU2104['MAD'] = time(17,  0).isoformat(timespec='minutes')
EU2104['ZGZ'] = time(20,  0).isoformat(timespec='minutes')

EU2105 = OrderedDict()
EU2105[' ']  = 'EU2105'
EU2105['SEV'] = time(16,  0).isoformat(timespec='minutes')
EU2105['TOL'] = time(18, 45).isoformat(timespec='minutes')
EU2105['MAD'] = time(19, 30).isoformat(timespec='minutes')
EU2105['ZGZ'] = time(22, 30).isoformat(timespec='minutes')

EU2201 = OrderedDict()
EU2201[' ']  = 'EU2201'
EU2201['ZGZ'] = time( 6, 15).isoformat(timespec='minutes')
EU2201['MAD'] = time( 9, 15).isoformat(timespec='minutes')
EU2201['TOL'] = time(10,  0).isoformat(timespec='minutes')
EU2201['SEV'] = time(12, 45).isoformat(timespec='minutes')

EU2202 = OrderedDict()
EU2202[' ']  = 'EU2202'
EU2202['ZGZ'] = time( 8, 30).isoformat(timespec='minutes')
EU2202['MAD'] = time(11, 30).isoformat(timespec='minutes')
EU2202['TOL'] = time(12, 15).isoformat(timespec='minutes')
EU2202['SEV'] = time(15,  0).isoformat(timespec='minutes')

EU2203 = OrderedDict()
EU2203[' ']  = 'EU2203'
EU2203['ZGZ'] = time(10, 45).isoformat(timespec='minutes')
EU2203['MAD'] = time(13, 45).isoformat(timespec='minutes')
EU2203['TOL'] = time(14, 30).isoformat(timespec='minutes')
EU2203['SEV'] = time(17, 15).isoformat(timespec='minutes')

EU2204 = OrderedDict()
EU2204[' ']  = 'EU2204'
EU2204['ZGZ'] = time(13,  0).isoformat(timespec='minutes')
EU2204['MAD'] = time(16,  0).isoformat(timespec='minutes')
EU2204['TOL'] = time(16, 45).isoformat(timespec='minutes')
EU2204['SEV'] = time(19, 30).isoformat(timespec='minutes')

EU2205 = OrderedDict()
EU2205[' ']  = 'EU2205'
EU2205['ZGZ'] = time(15, 30).isoformat(timespec='minutes')
EU2205['MAD'] = time(18, 30).isoformat(timespec='minutes')
EU2205['TOL'] = time(19, 15).isoformat(timespec='minutes')
EU2205['SEV'] = time(21, 45).isoformat(timespec='minutes')

AV1101 = OrderedDict()
AV1101[' ']  = 'AV1101'
AV1101['SGO'] = time( 6, 15).isoformat(timespec='minutes')
AV1101['VDD'] = time( 9, 15).isoformat(timespec='minutes')
AV1101['MAD'] = time(10,  0).isoformat(timespec='minutes')
AV1101['VLC'] = time(12, 45).isoformat(timespec='minutes')

AV1102 = OrderedDict()
AV1102[' ']  = 'AV1102'
AV1102['SGO'] = time( 8, 30).isoformat(timespec='minutes')
AV1102['VDD'] = time(11, 30).isoformat(timespec='minutes')
AV1102['MAD'] = time(12, 15).isoformat(timespec='minutes')
AV1102['VLC'] = time(15,  0).isoformat(timespec='minutes')

AV1103 = OrderedDict()
AV1103[' ']  = 'AV1103'
AV1103['SGO'] = time(10, 45).isoformat(timespec='minutes')
AV1103['VDD'] = time(13, 45).isoformat(timespec='minutes')
AV1103['MAD'] = time(14, 30).isoformat(timespec='minutes')
AV1103['VLC'] = time(17, 15).isoformat(timespec='minutes')

AV1104 = OrderedDict()
AV1104[' ']  = 'AV1104'
AV1104['SGO'] = time(13,  0).isoformat(timespec='minutes')
AV1104['VDD'] = time(16,  0).isoformat(timespec='minutes')
AV1104['MAD'] = time(16, 45).isoformat(timespec='minutes')
AV1104['VLC'] = time(19, 30).isoformat(timespec='minutes')

AV1105 = OrderedDict()
AV1105[' ']  = 'AV1105'
AV1105['SGO'] = time(15, 30).isoformat(timespec='minutes')
AV1105['VDD'] = time(18, 30).isoformat(timespec='minutes')
AV1105['MAD'] = time(19, 15).isoformat(timespec='minutes')
AV1105['VLC'] = time(21, 45).isoformat(timespec='minutes')

AV1201 = OrderedDict()
AV1201[' ']  = 'AV1201'
AV1201['VLC'] = time( 6, 30).isoformat(timespec='minutes')
AV1201['MAD'] = time( 9, 15).isoformat(timespec='minutes')
AV1201['VDD'] = time(10,  0).isoformat(timespec='minutes')
AV1201['SGO'] = time(13,  0).isoformat(timespec='minutes')

AV1202 = OrderedDict()
AV1202[' ']  = 'AV1202'
AV1202['VLC'] = time( 9,  0).isoformat(timespec='minutes')
AV1202['MAD'] = time(11, 45).isoformat(timespec='minutes')
AV1202['VDD'] = time(12, 30).isoformat(timespec='minutes')
AV1202['SGO'] = time(15, 30).isoformat(timespec='minutes')

AV1203 = OrderedDict()
AV1203[' ']  = 'AV1203'
AV1203['VLC'] = time(11, 15).isoformat(timespec='minutes')
AV1203['MAD'] = time(14,  0).isoformat(timespec='minutes')
AV1203['VDD'] = time(14, 45).isoformat(timespec='minutes')
AV1203['SGO'] = time(17, 45).isoformat(timespec='minutes')

AV1204 = OrderedDict()
AV1204[' ']  = 'AV1204'
AV1204['VLC'] = time(13, 30).isoformat(timespec='minutes')
AV1204['MAD'] = time(16, 15).isoformat(timespec='minutes')
AV1204['VDD'] = time(17,  0).isoformat(timespec='minutes')
AV1204['SGO'] = time(20,  0).isoformat(timespec='minutes')

AV1205 = OrderedDict()
AV1205[' ']  = 'AV1205'
AV1205['VLC'] = time(16,  0).isoformat(timespec='minutes')
AV1205['MAD'] = time(18, 45).isoformat(timespec='minutes')
AV1205['VDD'] = time(19, 30).isoformat(timespec='minutes')
AV1205['SGO'] = time(22, 30).isoformat(timespec='minutes')

lines = [EU1201, EU1202, EU1203, EU1204, EU1205, EU1301, EU1302, EU1303, EU1304, EU1305, EU2101, EU2102, EU2103, EU2104, EU2105, EU2201, EU2202, EU2203, EU2204, EU2205,
        AV1101, AV1102, AV1103, AV1104, AV1105, AV1201, AV1202, AV1203, AV1204, AV1205]
conn = ['ZGZ', 'VDD', 'BCN', 'VLC', 'MAD', 'SEV']

# %%
#The function Sch provides with a schedule of a line.

Sch(EU1204)
# Out:
# 	  EU1204
# 	BCN 12:00
# 	TRG 13:15
# 	VLC 15:45
# 	ALC 17:10
# 	MLG 19:45
# 	SEV 22:20

# %%
Sch(AV1103)
# Out:
# 	  AV1103
# 	SGO 10:45
# 	VDD 13:45
# 	MAD 14:30
# 	VLC 17:15

# %%
#The function Direct finds out whether two cities are directly connected and provides with a list of services.

def Direct(origin, destination):
    for l in lines:
        for k,v in l.items():
            if k == origin:
                for x,y in l.items():
                    if (x == destination) & (l[k] < l[x]):
                        print ('Line '+l[' '])
                        print (origin+'   '+l[k])
                        print (destination+'   '+l[x]+'\n----------\n')

# %%
#The Via function provides a connecting route between two cities and the schedules of the services available.

def Via(origin, destination):
    for l in lines:
        for k,v in l.items():
            if k == origin:
                for x,y in l.items():
                    if (x in conn) & (l[k] < l[x]):
                        pri = 0
                        for j in lines:
                            for a,b in j.items():
                                if a == x:
                                    for v,w in j.items():
                                        if (v == destination) & (l[x] < j[a] < j[v]) & (pri == 0):
                                            print ('Line '+l[' '])
                                            print (origin+'   '+l[k])
                                            print (x+'   '+l[x]+'\n')
                                            print ('Line '+j[' '])
                                            print (x+'   '+j[a])
                                            print (destination+'   '+j[v]+'\n----------\n')
                                            pri = 1

# %%
Direct('VLC', 'MLG')
# Out:
# Line EU1201
# VLC   09:45
# MLG   14:00
# ----------
#
# Line EU1202
# VLC   11:45
# MLG   16:00
# ----------
#
# Line EU1203
# VLC   13:25
# MLG   17:10
# ----------
#
# Line EU1204
# VLC   15:45
# MLG   19:45
# ----------
#
# Line EU1205
# VLC   17:35
# MLG   21:35
# ----------

# %%
Direct('ZGZ', 'MAD')
# Out:
# Line EU2201
# ZGZ   06:15
# MAD   09:15
# ----------
#
# Line EU2202
# ZGZ   08:30
# MAD   11:30
# ----------
#
# Line EU2203
# ZGZ   10:45
# MAD   13:45
# ----------
#
# Line EU2204
# ZGZ   13:00
# MAD   16:00
# ----------
#
# Line EU2205
# ZGZ   15:30
# MAD   18:30
# ----------

# %%
Via('ZGZ', 'VLC')
# Out:
# Line EU2201
# ZGZ   06:15
# MAD   09:15
#
# Line AV1101
# MAD   10:00
# VLC   12:45
# ----------
#
# Line EU2201
# ZGZ   06:15
# SEV   12:45
#
# Line EU1305
# SEV   13:45
# VLC   20:30
# ----------
#
# Line EU2202
# ZGZ   08:30
# MAD   11:30
#
# Line AV1102
# MAD   12:15
# VLC   15:00
# ----------
#
# Line EU2203
# ZGZ   10:45
# MAD   13:45
#
# Line AV1103
# MAD   14:30
# VLC   17:15
# ----------
#
# Line EU2204
# ZGZ   13:00
# MAD   16:00
#
# Line AV1104
# MAD   16:45
# VLC   19:30
# ----------
#
# Line EU2205
# ZGZ   15:30
# MAD   18:30
#
# Line AV1105
# MAD   19:15
# VLC   21:45
# ----------

# %%
Via('TOL', 'VLC')
# Out:
# Line EU2101
# TOL   09:15
# MAD   10:00
#
# Line AV1102
# MAD   12:15
# VLC   15:00
# ----------
#
# Line EU2102
# TOL   11:45
# MAD   12:30
#
# Line AV1103
# MAD   14:30
# VLC   17:15
# ----------
#
# Line EU2103
# TOL   14:00
# MAD   14:45
#
# Line AV1104
# MAD   16:45
# VLC   19:30
# ----------
#
# Line EU2104
# TOL   16:15
# MAD   17:00
#
# Line AV1105
# MAD   19:15
# VLC   21:45
# ----------
#
# Line EU2201
# TOL   10:00
# SEV   12:45
#
# Line EU1305
# SEV   13:45
# VLC   20:30
# ----------

# %%
#This is the very first prototype for this functions; I created it with 2 months experience in Python. 
#This can be improved by changing the variables that hold the information and creating more simple functions 
#to provide with the matches. With this project I am showing how seemingly hard tasks can have simple solutions
#that, at least, can serve as an MVP. I look forward to having bigger datasets on routes and schedules that
#allow for more features, and also improving on the code of these functions.
